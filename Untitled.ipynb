# %% [raw]
# 1) seller_type column is not important

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import  LinearRegression
from xgboost import XGBRegressor
from sklearn.metrics  import r2_score

# %%
df=pd.read_csv("../../datasets/Internship_25_car_prediction_dataset/CAR DETAILS FROM CAR DEKHO.csv")

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
df.tail()
# Out:
#                                      name  year  selling_price  km_driven  \
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# 4335  Diesel  Individual       Manual  Second Owner
# 4336  Diesel  Individual       Manual  Second Owner
# 4337  Petrol  Individual       Manual  Second Owner
# 4338  Diesel  Individual       Manual   First Owner
# 4339  Petrol  Individual       Manual   First Owner

# %%
df.describe()
# Out:
#               year  selling_price      km_driven
# count  4340.000000   4.340000e+03    4340.000000
# mean   2013.090783   5.041273e+05   66215.777419
# std       4.215344   5.785487e+05   46644.102194
# min    1992.000000   2.000000e+04       1.000000
# 25%    2011.000000   2.087498e+05   35000.000000
# 50%    2014.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %%
df.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %%
df['seller_type'].unique()
# Out:
# array(['Individual', 'Dealer', 'Trustmark Dealer'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB

# %% [markdown]
# # drop unwanted column

# %%
df1=df.drop('seller_type',axis=1)

# %%
df1
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel transmission         owner
# ...

# %% [markdown]
# # convert all values in int

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   transmission   4340 non-null   object
#  6   owner          4340 non-null   object
# dtypes: int64(3), object(4)
# memory usage: 237.5+ KB

# %% [markdown]
# #chatgpt give one hot encoding to do this
# it is best practice

# %%
# from sklearn.preprocessing import OneHotEncoder
# ohe = OneHotEncoder()

# encoded = ohe.fit_transform(df[['Fuel_Type']]).toarray()
# encoded_df = pd.DataFrame(encoded, columns=ohe.get_feature_names_out(['Fuel_Type']))

# df = pd.concat([df.drop('Fuel_Type', axis=1), encoded_df], axis=1)

# %%
df1['fuel'].unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG', 'LPG', 'Electric'], dtype=object)

# %%
#i tried to do map but in column fuel some rows have space in their name so not match == This usually happens when the actual values in the column don't match the dictionary keys exactly.
#so now we strip the value
df1['fuel']=df1['fuel'].str.strip()

# %%
df1['fuel']=df1['fuel'].map({'Petrol':0,'Diesel':1,'CNG':2,'LPG':3,'Electric':4})

# %%
df['fuel'].isnull().sum()
# Out:
# 0

# %%
df1
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#       fuel transmission         owner
# 0        0       Manual   First Owner
# ...

# %%
df1['fuel'].value_counts()
# Out:
# fuel
# 1    2153
# 0    2123
# 2      40
# 3      23
# 4       1
# Name: count, dtype: int64

# %% [raw]
# # TRANSMISSION

# %%
df1['transmission'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
df1['transmission']=df1['transmission'].str.strip()  #if any sapces comes in rows then it rwmove

# %%
df1['transmission']=df1['transmission'].map({'Manual':0,'Automatic':1})

# %%
df1['transmission'].value_counts()
# Out:
# transmission
# 0    3892
# 1     448
# Name: count, dtype: int64

# %% [raw]
# # OWNER

# %%
df1['owner'].unique()
# Out:
# array(['First Owner', 'Second Owner', 'Fourth & Above Owner',
#        'Third Owner', 'Test Drive Car'], dtype=object)

# %%
df1['owner']=df1['owner'].str.strip()

# %%
df1['owner']=df1['owner'].map({'First Owner':0, 'Second Owner':1, 'Fourth & Above Owner':2, 'Third Owner':3, 'Test Drive Car':4})

# %%
df['owner'].value_counts()
# Out:
# owner
# First Owner             2832
# Second Owner            1106
# Third Owner              304
# Fourth & Above Owner      81
# Test Drive Car            17
# Name: count, dtype: int64

# %% [raw]
# # NAME

# %%
#removing extra spaces
df['name']=df['name'].str.strip()

# %%
df1['name'].count()
# Out:
# 4340

# %%
len(df1['name'].unique())
# Out:
# 1491

# %%
df1['name'].value_counts()
# Out:
# name
# Maruti Swift Dzire VDI                     69
# Maruti Alto 800 LXI                        59
# Maruti Alto LXi                            47
# Maruti Alto LX                             35
# Hyundai EON Era Plus                       35
#                                            ..
# Hyundai Verna Transform CRDi VGT SX ABS     1
# Maruti S-Presso VXI Plus                    1
# Toyota Etios Liva 1.2 VX                    1
# Toyota Yaris G                              1
# Hyundai i20 Magna 1.4 CRDi                  1
# Name: count, Length: 1491, dtype: int64

# %%
#trail for 1 row
a=df1['name'][0]
a
# Out:
# 'Maruti 800 AC'

# %%
df1['name'][0].split()
# Out:
# ['Maruti', '800', 'AC']

# %%
#trail for 1 row
' '.join(a.split()[1:])
# Out:
# '800 AC'

# %%
Brand=[]
for i in df['name']:
    a=i.split()[0]
    Brand.append(a)

# %%
df1['Brand']=Brand

# %%
Model=[]
for i in df['name']:
    a=i.split()[1:3]
    b=' '.join(a) #join the 2 words 
    Model.append(b)

# %%
df1['Model']=Model

# %%
df1
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#       fuel  transmission  owner    Brand      Model
# ...

# %%
len(df1['Brand'].unique())
# Out:
# 29

# %%
len(df1['Model'].unique())
# Out:
# 613

# %%
df1['Model'].value_counts().head(100)
# Out:
# Model
# Wagon R         164
# Swift Dzire     139
# Grand i10       112
# Alto 800         87
# Innova 2.5       83
#                ...
# X5 xDrive        11
# Baleno Zeta      11
# City i-VTEC      11
# EON 1.0          11
# Scorpio 1.99     11
# Name: count, Length: 100, dtype: int64

# %%
df1['Model'][:101] #it is not that value where count is greater so its not right to do
# Out:
# 0          800 AC
# 1         Wagon R
# 2       Verna 1.6
# 3        RediGO T
# 4        Amaze VX
#           ...
# 96         A8 4.2
# 97     RediGO 1.0
# 98      Jetta 1.4
# 99         A4 2.0
# 100     Civic 1.8
# Name: Model, Length: 101, dtype: object

# %%
a=df1['Model'].value_counts().head(100).index

# %%
len(a)
# Out:
# 100

# %%
b=df1['Model'].value_counts()[101:]

# %%
b.index
# Out:
# Index(['EON D', 'Etios GD', 'Tavera Neo', 'Grande Punto', 'Verna SX',
#        'Rapid 1.6', 'Xcent 1.1', 'Ciaz 1.4', 'XUV500 AT', 'Celerio ZXI',
#        ...
#        'Vento Celeste', 'Ecosport Thunder', 'Accord VTi-L', 'i10 Asta',
#        'Koleos 2.0', 'Ikon 1.8', 'Linea Classic', 'Punto 1.2', 'XJ 5.0',
#        'Nano XM'],
#       dtype='object', name='Model', length=512)

# %%
#this tried by me but not getting what i want
# for i in b.index:
#     a=i.replace(i,'other')
#     #print(a)

# %%
df1['Model']
# Out:
# 0          800 AC
# 1         Wagon R
# 2       Verna 1.6
# 3        RediGO T
# 4        Amaze VX
#           ...
# 4335    i20 Magna
# 4336    i20 Magna
# 4337       800 AC
# 4338    Creta 1.6
# 4339     KWID RXT
# Name: Model, Length: 4340, dtype: object

# %%
df1['Model']=df1['Model'].apply(lambda x:x if x in a else 'Other')

# %%
df1['Model'].value_counts()
# Out:
# Model
# Other           1575
# Wagon R          164
# Swift Dzire      139
# Grand i10        112
# Alto 800          87
#                 ...
# EON 1.0           11
# Scorpio 1.99      11
# City i-VTEC       11
# Baleno Zeta       11
# Indigo LS         11
# Name: count, Length: 101, dtype: int64

# %%
#checking ki ji value apan others la takli ahe ti nahi ne atta
'EON D' in df1['Model']
# Out:
# False

# %%
df1
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#       fuel  transmission  owner    Brand      Model
# ...

# %%
len(df1['Model'].unique())
# Out:
# 101

# %%
len(df1['Brand'].value_counts()) #from both method used
# Out:
# 29

# %% [raw]
# # WE USE LABELENCODER BECAUSE THE NUMBER OF UNIQUE VALUES IS LARGE, MAKING MANUAL ENCODING IMPRACTICAL

# %%
le_Model=LabelEncoder()
le_Brand=LabelEncoder()

# %%
df1['Model']=le_Model.fit_transform(df1['Model'])
df1['Brand']=le_Brand.fit_transform(df1['Brand'])

# %%
df1
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#       fuel  transmission  owner  Brand  Model
# ...

# %% [markdown]
# # model building

# %%
X=df1[['year','km_driven','fuel','transmission','owner','Brand','Model']]
y=df1['selling_price']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=34)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((3472, 7), (868, 7), (3472,), (868,))

# %% [markdown]
# #MIN MAX SCALER

# %%
scaler=MinMaxScaler()

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train_scaled=scaler.transform(X_train)

# %%
model=LinearRegression()

# %%
model.fit(X_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
X_test_scaled=scaler.transform(X_test)

# %%
model.score(X_test_scaled,y_test)
# Out:
# 0.4680527941721381

# %% [markdown]
# # XGBoost

# %%
xgb_model=XGBRegressor()
xgb_model.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
y_pred=xgb_model.predict(X_test)

# %%
score = r2_score(y_test, y_pred)

# %%
score
# Out:
# 0.8809208273887634

# %% [markdown]
# # model deploy

# %%
import pickle

# %%
with open('xgb_model.pkl','wb') as f:
    pickle.dump(xgb_model,f)

# %%
with open('le_brand.pkl', 'wb') as f:
    pickle.dump(le_Brand, f)

with open('le_model.pkl', 'wb') as f:
    pickle.dump(le_Model, f)

# %%
with open('linear_model.pkl','wb') as f:
    pickle.dump(model,f)

# %%
with open('scaler.pkl','wb') as f:
    pickle.dump(scaler,f)
